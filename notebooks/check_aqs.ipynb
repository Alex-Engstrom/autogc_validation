# %%
from aqs_tools import summarize_nulls_by_hour, summarize_qualifiers_by_hour, summarize_nulls_by_compound, summarize_qualifiers_by_compound
from aqs_tools.constants import aqs_to_name, name_to_aqs
from pathlib import Path

# %% [markdown]
# # RB June

# %%
june_rd = Path(r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_06-01-2025_to_06-30-2025 (3).txt")
june_nulls = summarize_nulls_by_hour(june_rd, "RD")
display(june_nulls)

long = summarize_qualifiers_by_hour(june_rd, "RD")
display(long)

nulls_by_compound = summarize_nulls_by_compound(june_rd, "RD")
display(nulls_by_compound)

quals = summarize_qualifiers_by_compound(june_rd, "RD")
quals = {aqs_to_name(int(key)): value for key, value in quals.items()}
display(quals)

# %% [markdown]
# ## RB July

# %%
name = aqs_to_name(43226)
print(name)
file = r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_07-01-2025_to_07-31-2025 (2).txt"
nullshr = summarize_nulls_by_hour(file, "RD", threshold = 50)
display(nullshr)

qualshr = summarize_qualifiers_by_hour(file, "RD")
display(long)

nullscd = summarize_nulls_by_compound(file, "RD")
display(nullscd)

qualscd = summarize_qualifiers_by_compound(file, "RD")
qualscd = {aqs_to_name(int(key)): value for key, value in qualscd.items()}
display(qualscd)

# %% [markdown]
# ## RB September

# %%
file = r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_09-01-2025_to_09-30-2025 (2).txt"
nullshr = summarize_nulls_by_hour(file, "RD", threshold = 50)
display(nullshr)

qualshr = summarize_qualifiers_by_hour(file, "RD")
display(long)

nullscd = summarize_nulls_by_compound(file, "RD")
display(nullscd)

qualscd = summarize_qualifiers_by_compound(file, "RD")
qualscd = {aqs_to_name(int(key)): value for key, value in qualscd.items()}
display(qualscd)

# %% [markdown]
# ## October

# %%
file = r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_10-01-2025_to_10-31-2025.txt"
nullshr = summarize_nulls_by_hour(file, "RD", threshold = 50)
display(nullshr)

qualshr = summarize_qualifiers_by_hour(file, "RD")
display(long)

nullscd = summarize_nulls_by_compound(file, "RD")
display(nullscd)

qualscd = summarize_qualifiers_by_compound(file, "RD")
qualscd = {aqs_to_name(int(key)): value for key, value in qualscd.items()}
display(qualscd)

# %% [markdown]
# ## RB November

# %%
file = r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_11-01-2025_to_11-30-2025.txt"
nullshr = summarize_nulls_by_hour(file, "RD", threshold = 50)
display(nullshr)

qualshr = summarize_qualifiers_by_hour(file, "RD")
display(long)

nullscd = summarize_nulls_by_compound(file, "RD")
display(nullscd)

qualscd = summarize_qualifiers_by_compound(file, "RD")
qualscd = {aqs_to_name(int(key)): value for key, value in qualscd.items()}
display(qualscd)

# %% [markdown]
# ## RB December

# %%
file = r"D:\autogc_validation\notebooks\aqs_files_to_review\RD_SITE-RB_RedButte_INSERT_12-01-2025_to_12-31-2025 (1).txt"
nullshr = summarize_nulls_by_hour(file, "RD", threshold = 50)
display(nullshr)

qualshr = summarize_qualifiers_by_hour(file, "RD")
display(long)

nullscd = summarize_nulls_by_compound(file, "RD")
display(nullscd)

qualscd = summarize_qualifiers_by_compound(file, "RD")
qualscd = {aqs_to_name(int(key)): value for key, value in qualscd.items()}
display(qualscd)
# Out:
# {'AF': 1,
#  'AM': 1,
#  'AN': 39,
#  'AQ': 1,
#  'AS': 0,
#  'AT': 4,
#  'AY': 76,
#  'BA': 18,
#  'BJ': 2,
#  'TC': 4,
#  'XX': 1,
#  'total': 147}
# {'LB': 0, 'LJ': 0, 'MD': 0, 'ND': 0, 'QX': 0, 'SQ': 0, 'total': 0}
# {'43102': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 77,
#   'AT': 4,
#   'AY': 65,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 531,
#   'total': 744},
#  '43141': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43202': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43203': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 16,
#   'AT': 4,
#   'AY': 74,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 583,
#   'total': 744},
#  '43204': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43205': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 35,
#   'AT': 4,
#   'AY': 73,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 565,
#   'total': 744},
#  '43206': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43212': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 29,
#   'AT': 4,
#   'AY': 69,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 575,
#   'total': 744},
#  '43214': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 53,
#   'AT': 4,
#   'AY': 69,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 551,
#   'total': 744},
#  '43216': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43217': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43218': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43220': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 126,
#   'AT': 4,
#   'AY': 58,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 3,
#   'XX': 1,
#   'no_null': 490,
#   'total': 744},
#  '43221': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43224': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43226': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43227': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43230': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 11,
#   'AT': 4,
#   'AY': 73,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 589,
#   'total': 744},
#  '43231': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43232': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43233': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43235': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43238': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43242': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43243': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43244': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43245': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43247': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43248': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43249': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43250': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43252': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43253': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43261': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43262': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43263': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43280': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43284': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43285': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AS': 1,
#   'AT': 4,
#   'AY': 75,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43291': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43954': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '43960': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45109': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45201': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45202': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45203': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45204': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45207': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45208': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45209': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45210': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45211': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45212': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45213': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45218': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45219': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45220': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744},
#  '45225': {'AF': 1,
#   'AM': 1,
#   'AN': 39,
#   'AQ': 1,
#   'AT': 4,
#   'AY': 76,
#   'BA': 18,
#   'BJ': 2,
#   'TC': 4,
#   'XX': 1,
#   'no_null': 597,
#   'total': 744}}
# {'TNMHC': {'LB': 95, 'no_qualifier': 649, 'total': 744},
#  'N-dodecane': {'LB': 34,
#   'LJ': 744,
#   'MD': 527,
#   'ND': 105,
#   'SQ': 67,
#   'no_qualifier': 0,
#   'total': 744},
#  'Ethane': {'no_qualifier': 744, 'total': 744},
#  'Ethylene': {'LB': 143,
#   'MD': 19,
#   'ND': 1,
#   'SQ': 132,
#   'no_qualifier': 479,
#   'total': 744},
#  'Propane': {'EH': 7, 'SQ': 2, 'no_qualifier': 735, 'total': 744},
#  'Propylene': {'LB': 37,
#   'LJ': 47,
#   'MD': 212,
#   'ND': 128,
#   'SQ': 174,
#   'no_qualifier': 337,
#   'total': 744},
#  'Acetylene': {'LB': 47,
#   'MD': 22,
#   'ND': 1,
#   'SQ': 163,
#   'no_qualifier': 522,
#   'total': 744},
#  'N-butane': {'EH': 1,
#   'LB': 73,
#   'MD': 7,
#   'QX': 37,
#   'SQ': 41,
#   'no_qualifier': 606,
#   'total': 744},
#  'Iso-butane': {'EH': 1,
#   'LB': 71,
#   'LJ': 47,
#   'MD': 85,
#   'ND': 55,
#   'SQ': 188,
#   'no_qualifier': 443,
#   'total': 744},
#  'Trans-2-butene': {'MD': 479,
#   'ND': 334,
#   'SQ': 120,
#   'no_qualifier': 145,
#   'total': 744},
#  'Cis-2-butene': {'MD': 380,
#   'ND': 33,
#   'SQ': 215,
#   'no_qualifier': 149,
#   'total': 744},
#  '1,3-butadiene': {'MD': 510,
#   'ND': 43,
#   'QX': 37,
#   'SQ': 113,
#   'no_qualifier': 117,
#   'total': 744},
#  'N-pentane': {'LB': 143, 'MD': 3, 'ND': 1, 'no_qualifier': 598, 'total': 744},
#  'Iso-pentane': {'MD': 61,
#   'ND': 3,
#   'SQ': 226,
#   'no_qualifier': 457,
#   'total': 744},
#  '1-pentene': {'LB': 73,
#   'MD': 176,
#   'ND': 29,
#   'SQ': 263,
#   'no_qualifier': 239,
#   'total': 744},
#  'Trans-2-pentene': {'LB': 21,
#   'MD': 456,
#   'ND': 331,
#   'SQ': 121,
#   'no_qualifier': 161,
#   'total': 744},
#  'Cis-2-pentene': {'LB': 45,
#   'MD': 511,
#   'ND': 354,
#   'SQ': 97,
#   'no_qualifier': 124,
#   'total': 744},
#  '3-methylpentane': {'LB': 47,
#   'MD': 81,
#   'ND': 3,
#   'SQ': 242,
#   'no_qualifier': 380,
#   'total': 744},
#  'N-hexane': {'MD': 27,
#   'ND': 10,
#   'SQ': 185,
#   'no_qualifier': 532,
#   'total': 744},
#  'N-heptane': {'LB': 12,
#   'MD': 95,
#   'ND': 19,
#   'SQ': 217,
#   'no_qualifier': 425,
#   'total': 744},
#  'N-octane': {'MD': 292,
#   'ND': 34,
#   'SQ': 217,
#   'no_qualifier': 235,
#   'total': 744},
#  'N-nonane': {'MD': 335,
#   'ND': 24,
#   'SQ': 178,
#   'no_qualifier': 231,
#   'total': 744},
#  'N-decane': {'LB': 47,
#   'LJ': 284,
#   'MD': 202,
#   'ND': 96,
#   'SQ': 202,
#   'no_qualifier': 192,
#   'total': 744},
#  'Cyclopentane': {'MD': 501,
#   'ND': 108,
#   'SQ': 91,
#   'no_qualifier': 152,
#   'total': 744},
#  'Isoprene': {'MD': 443,
#   'ND': 185,
#   'SQ': 152,
#   'no_qualifier': 149,
#   'total': 744},
#  '2,2-dimethylbutane': {'MD': 324,
#   'ND': 78,
#   'SQ': 218,
#   'no_qualifier': 202,
#   'total': 744},
#  '1-hexene': {'LJ': 744,
#   'MD': 485,
#   'ND': 267,
#   'SQ': 127,
#   'no_qualifier': 0,
#   'total': 744},
#  '2,4-dimethylpentane': {'MD': 250,
#   'ND': 124,
#   'SQ': 203,
#   'no_qualifier': 291,
#   'total': 744},
#  'Cyclohexane': {'MD': 395,
#   'ND': 183,
#   'SQ': 163,
#   'no_qualifier': 186,
#   'total': 744},
#  '3-methylhexane': {'LB': 34,
#   'MD': 245,
#   'ND': 59,
#   'SQ': 192,
#   'no_qualifier': 285,
#   'total': 744},
#  '2,2,4-trimethylpentane': {'MD': 109,
#   'ND': 51,
#   'SQ': 159,
#   'no_qualifier': 476,
#   'total': 744},
#  '2,3,4-trimethylpentane': {'LB': 47,
#   'MD': 251,
#   'ND': 148,
#   'SQ': 188,
#   'no_qualifier': 300,
#   'total': 744},
#  '3-methylheptane': {'MD': 422,
#   'ND': 131,
#   'SQ': 160,
#   'no_qualifier': 162,
#   'total': 744},
#  'Methylcyclohexane': {'MD': 218,
#   'ND': 82,
#   'SQ': 184,
#   'no_qualifier': 342,
#   'total': 744},
#  'Methylcyclopentane': {'MD': 55,
#   'ND': 9,
#   'SQ': 299,
#   'no_qualifier': 390,
#   'total': 744},
#  '2-methylhexane': {'MD': 105,
#   'ND': 79,
#   'SQ': 171,
#   'no_qualifier': 468,
#   'total': 744},
#  '1-butene': {'LB': 122,
#   'LJ': 284,
#   'MD': 309,
#   'ND': 186,
#   'SQ': 193,
#   'no_qualifier': 116,
#   'total': 744},
#  '2,3-dimethylbutane': {'MD': 437,
#   'ND': 24,
#   'SQ': 136,
#   'no_qualifier': 171,
#   'total': 744},
#  '2-methylpentane': {'LB': 239,
#   'MD': 11,
#   'ND': 2,
#   'SQ': 185,
#   'no_qualifier': 327,
#   'total': 744},
#  '2,3-dimethylpentane': {'LB': 34,
#   'MD': 96,
#   'ND': 80,
#   'SQ': 138,
#   'no_qualifier': 481,
#   'total': 744},
#  'N-undecane': {'MD': 376,
#   'ND': 79,
#   'SQ': 164,
#   'no_qualifier': 204,
#   'total': 744},
#  '2-methylheptane': {'LB': 71,
#   'MD': 320,
#   'ND': 125,
#   'SQ': 187,
#   'no_qualifier': 207,
#   'total': 744},
#  'M&p-xylene': {'MD': 116,
#   'ND': 1,
#   'QX': 37,
#   'SQ': 254,
#   'no_qualifier': 356,
#   'total': 744},
#  'Benzene': {'MD': 23, 'ND': 2, 'SQ': 188, 'no_qualifier': 533, 'total': 744},
#  'Toluene': {'LB': 71, 'SQ': 127, 'no_qualifier': 562, 'total': 744},
#  'Ethylbenzene': {'MD': 415,
#   'ND': 15,
#   'SQ': 168,
#   'no_qualifier': 161,
#   'total': 744},
#  'O-xylene': {'MD': 67, 'ND': 5, 'SQ': 235, 'no_qualifier': 442, 'total': 744},
#  '1,3,5-tri-m-benzene': {'MD': 369,
#   'ND': 223,
#   'SQ': 149,
#   'no_qualifier': 226,
#   'total': 744},
#  '1,2,4-tri-m-benzene': {'MD': 484,
#   'ND': 6,
#   'QX': 37,
#   'SQ': 127,
#   'no_qualifier': 129,
#   'total': 744},
#  'N-propylbenzene': {'MD': 597,
#   'ND': 262,
#   'QX': 37,
#   'SQ': 27,
#   'no_qualifier': 116,
#   'total': 744},
#  'Iso-propylbenzene': {'MD': 594,
#   'ND': 425,
#   'SQ': 29,
#   'no_qualifier': 121,
#   'total': 744},
#  'O-ethyltoluene': {'MD': 417,
#   'ND': 145,
#   'SQ': 156,
#   'no_qualifier': 171,
#   'total': 744},
#  'M-ethyltoluene': {'LB': 45,
#   'MD': 2,
#   'SQ': 501,
#   'no_qualifier': 218,
#   'total': 744},
#  'P-ethyltoluene': {'LB': 48,
#   'MD': 266,
#   'ND': 66,
#   'SQ': 246,
#   'no_qualifier': 215,
#   'total': 744},
#  'M-diethylbenzene': {'LJ': 744,
#   'MD': 622,
#   'ND': 506,
#   'SQ': 1,
#   'no_qualifier': 0,
#   'total': 744},
#  'P-diethylbenzene': {'LJ': 744,
#   'MD': 623,
#   'ND': 65,
#   'QX': 744,
#   'SQ': 1,
#   'no_qualifier': 0,
#   'total': 744},
#  'Styrene': {'MD': 426,
#   'ND': 213,
#   'SQ': 137,
#   'no_qualifier': 181,
#   'total': 744},
#  '1,2,3-tri-m-benzene': {'MD': 323,
#   'ND': 3,
#   'SQ': 295,
#   'no_qualifier': 126,
#   'total': 744}}
