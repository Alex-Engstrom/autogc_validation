# %%
from autogc_validation.workspace import start_month
result = start_month(
    sites = ['EQ'],
    project_dir = r"C:\Users\aengstrom\Documents\Python\autogc_validation",
    year = 2025,
    month = 4)

# %%
from autogc_validation.database.management.init_db import initialize_database
initialize_database(r"C:\Users\aengstrom\Documents\Python\autogc_validation\data\autogc.db")

# %%
  import autogc_validation.workspace
  print(autogc_validation.workspace.__file__)
# Out:
# C:\Users\aengstrom\Documents\Python\autogc_validation\src\autogc_validation\workspace\__init__.py
